# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from PIL import Image

# %%
pic = np.array(Image.open('images/panda.JPG').resize(1000,1000))
pic_tensor = torch.from_numpy(pic)
pic_tensor.size()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-c137d273e6ca> in <module>
# ----> 1 pic = np.array(Image.open('images/panda.JPG').resize(1000,1000))
#       2 pic_tensor = torch.from_numpy(pic)
#       3 pic_tensor.size()
#
# ~/.conda/envs/sdesign/lib/python3.7/site-packages/PIL/Image.py in resize(self, size, resample, box)
#    1782                 NEAREST, BILINEAR, BICUBIC, LANCZOS, BOX, HAMMING,
#    1783         ):
# -> 1784             raise ValueError("unknown resampling filter")
#    1785
#    1786         size = tuple(size)
#
# ValueError: unknown resampling filter

# %%
plt.imshow(pic)

# %%
plt.imshow(pic_tensor[1:600,:,0].numpy())

# %%
plt.imshow(pic_tensor[:,:,1].numpy());

# %%
plt.imshow(pic_tensor[:,:,2].numpy());

# %%
for i=0 i<pic_tensor.size()[1]
# Out:
#   File "<ipython-input-33-32cf02cd89fe>", line 1
#     for i=0 i<pic_tensor.size()[1]
#          ^
# SyntaxError: invalid syntax
